# %%
# %run test.py
# Out:
# Hello MY World!

# %%
# %run -t -N3 test.py
# Out:
# Hello MY World!
# Hello MY World!
# Hello MY World!
#
# IPython CPU timings (estimated):
# Total runs performed: 3
#   Times  :      Total      Per run
#   User   :       0.00 s,       0.00 s.
#   System :       0.00 s,       0.00 s.
# Wall time:       0.00 s.

# %%
import test

# %%
# %Load

# %%
# %load test.py
print("Hello World!")
# Out:
# Hello World!

# %%
# %%writefile test.py
# %load test.py
print('Hello MY World!')
# Out:
# Overwriting test.py

# %%
# %run test.py
# Out:
# Hello MY World!

# %%
# !notepad test.py
