# %% [markdown]
# # Paycheck Calculator
# **Developer:** Joshua Mann
# **Course:** LIS4376_5377 - Artificial Intelligence Applications
#
# **Program requirements:**
#
#     1. Must use float data type for user input except.
#     2. Must round calculations to two decimal places.
#     3. Must format currency with dollar sign, and two decimal places.

# %%
# IPO:
# input:
print("\nUser Input: ")
hours = float(input("Hours Worked: "))
hourly_rate = float(input("Hourly Rate: $"))
tax_rate = float(input("Tax Rate (percent): "))
# Out:
# User Input:
# Hours Worked:  40
# Hourly Rate: $ 50
# Tax Rate (percent):  25

# %%
# process:
gross_pay = hours * hourly_rate
tax_amount = gross_pay * (tax_rate / 100)
net_pay = gross_pay - tax_amount

# %%
# output:
# display results
# formatting:
print("\nProgram Output:")
print("Gross Pay:\t", "${0:,.2f}".format(gross_pay))
print("Tax Rate:\t", "{0:.2%}".format(tax_rate/100))
print("Tax Amount:\t", "${0:,.2f}".format(tax_amount))
print("Net Pay:\t", "${0:,.2f}".format(net_pay))
# Out:
# Program Output:
# Gross Pay:	 $2,000.00
# Tax Rate:	 25.00%
# Tax Amount:	 $500.00
# Net Pay:	 $1,500.00
